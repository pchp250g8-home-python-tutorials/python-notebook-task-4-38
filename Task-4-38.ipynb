# %% [markdown]
# Три трактора разной производительности вспахивают два поля разной величины. Третий трактор может
# вспахать второе поле на 3 ч. быстрее, чем первый вспашет первое поле, но на 2 ч. медленнее, чем второй может
# вспахать первое поле. Первый и второй тракторы вместе могут  вспахать первое поле на 6 ч. быстрее, чем
# третий вспашет второе поле. За сколько часов третий трактор вспашет второе поле?

# %%
from sympy import Eq
from sympy import solve
from sympy import symbols

x,y,z,s1,s2 = symbols("x y z s1 s2")

sys_eq = [Eq(s1 / x  - s2 / z , 3), 
          Eq(s2 / z - s1 / y , 2), 
          Eq(s2 / z - (s1 / (x + y)) , 6)]
sol = solve(sys_eq, [x, y, z])
print(sol)
print([s1 / sol[0][0], s1 / sol[0][1], s2 / sol[0][2]])
# Out:
# [(s1/15, s1/10, s2/12)]
# [15, 10, 12]

# %%
from sympy.abc import x
from sympy import Eq
from sympy import solve

eq = Eq(1 / (x + 3) + 1 / (x - 2), 1 / (x - 6))
sol = solve(eq, x)
print([sol[1] + 3, sol[1] - 2, sol[1]])
# Out:
# [15, 10, 12]
